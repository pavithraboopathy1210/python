# %%
import pandas as pd

# %%
df=pd.read_csv("pandas_practice.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(10)
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 83           84         0       1         Carrau, Mr. Francisco M    male
# 39           40         1       3     Nicola-Yarred, Miss. Jamila  female
# 77           78         0       3        Moutal, Mr. Rahamin Haim    male
# 91           92         0       3      Andreasson, Mr. Paul Edvin    male
# 35           36         0       1  Holverson, Mr. Alexander Oskar    male
# 94           95         0       3               Coxon, Mr. Daniel    male
# 57           58         0       3             Novel, Mr. Mansouer    male
# 60           61         0       3           Sirayanian, Mr. Orsen    male
# 37           38         0       3        Cann, Mr. Ernest Charles    male
# 80           81         0       3            Waelens, Mr. Achille    male
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 83  28.0      0      0      113059  47.1000   NaN        S
# ...

# %%
df.loc[[0,1,5]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 5      0     330877   8.4583   NaN        Q

# %%
df.loc[43:50]
# Out:
#     PassengerId  Survived  Pclass  \
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
# 50           51         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 43       Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1      2
# 44                  Devaney, Miss. Margaret Delia  female  19.0      0      0
# 45                       Rogers, Mr. William John    male   NaN      0      0
# 46                              Lennon, Mr. Denis    male   NaN      1      0
# 47                      O'Driscoll, Miss. Bridget  female   NaN      0      0
# 48                            Samaan, Mr. Youssef    male   NaN      2      0
# 49  Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1      0
# ...

# %%
df.loc[43:45,["Name","Age"]]
# Out:
#                                         Name   Age
# 43  Laroche, Miss. Simonne Marie Anne Andree   3.0
# 44             Devaney, Miss. Margaret Delia  19.0
# 45                  Rogers, Mr. William John   NaN

# %%
df.loc[1,"Age"]=20.0

# %%
df.iloc[44,5]
# Out:
# np.float64(19.0)

# %%
df.Age
# Out:
# 0     22.0
# 1     20.0
# 2     26.0
# 3     35.0
# 4     35.0
#       ...
# 94    59.0
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# Name: Age, Length: 99, dtype: float64

# %%
df["Sex"]
# Out:
# 0       male
# 1     female
# 2     female
# 3     female
# 4       male
#        ...
# 94      male
# 95      male
# 96      male
# 97      male
# 98    female
# Name: Sex, Length: 99, dtype: object

# %% [markdown]
# **FILTERING DATA**

# %%
df.sort_values("Age")
# Out:
#     PassengerId  Survived  Pclass                                      Name  \
# 78           79         1       2             Caldwell, Master. Alden Gates
# 7             8         0       3            Palsson, Master. Gosta Leonard
# 16           17         0       3                      Rice, Master. Eugene
# 43           44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 10           11         1       3           Sandstrom, Miss. Marguerite Rut
# ..          ...       ...     ...                                       ...
# 76           77         0       3                         Staneff, Mr. Ivan
# 77           78         0       3                  Moutal, Mr. Rahamin Haim
# 82           83         1       3            McDermott, Miss. Brigdet Delia
# 87           88         0       3             Slocovski, Mr. Selman Francis
# 95           96         0       3               Shorney, Mr. Charles Joseph
#
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sort_values("Name")
# Out:
#     PassengerId  Survived  Pclass  \
# 40           41         0       3
# 4             5         0       3
# 68           69         1       3
# 13           14         0       3
# 91           92         0       3
# ..          ...       ...     ...
# 80           81         0       3
# 58           59         1       2
# 33           34         0       2
# 17           18         1       2
# 55           56         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 40  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 4                         Allen, Mr. William Henry    male  35.0      0
# 68                 Andersson, Miss. Erna Alexandra  female  17.0      4
# 13                     Andersson, Mr. Anders Johan    male  39.0      1
# 91                      Andreasson, Mr. Paul Edvin    male  20.0      0
# ..                                             ...     ...   ...    ...
# ...

# %%
df.sort_values(["Name","Age"])
# Out:
#     PassengerId  Survived  Pclass  \
# 40           41         0       3
# 4             5         0       3
# 68           69         1       3
# 13           14         0       3
# 91           92         0       3
# ..          ...       ...     ...
# 80           81         0       3
# 58           59         1       2
# 33           34         0       2
# 17           18         1       2
# 55           56         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 40  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 4                         Allen, Mr. William Henry    male  35.0      0
# 68                 Andersson, Miss. Erna Alexandra  female  17.0      4
# 13                     Andersson, Mr. Anders Johan    male  39.0      1
# 91                      Andreasson, Mr. Paul Edvin    male  20.0      0
# ..                                             ...     ...   ...    ...
# ...

# %%
df.sort_values(["Name","Age"],ascending=False)
# Out:
#     PassengerId  Survived  Pclass  \
# 55           56         1       1
# 17           18         1       2
# 33           34         0       2
# 58           59         1       2
# 80           81         0       3
# ..          ...       ...     ...
# 91           92         0       3
# 13           14         0       3
# 68           69         1       3
# 4             5         0       3
# 40           41         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 55                               Woolner, Mr. Hugh    male   NaN      0
# 17                    Williams, Mr. Charles Eugene    male   NaN      0
# 33                           Wheadon, Mr. Edward H    male  66.0      0
# 58                    West, Miss. Constance Mirium  female   5.0      1
# 80                            Waelens, Mr. Achille    male  22.0      0
# ..                                             ...     ...   ...    ...
# ...

# %% [markdown]
# **FILTERING DATA**

# %%
df.loc[df["Age"]>15]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 93           94         0       3
# 94           95         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df.loc[df["Age"]>15,["Name"]]
# Out:
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# ..                                                ...
# 93                            Dean, Mr. Bertram Frank
# 94                                  Coxon, Mr. Daniel
# 96                          Goldschmidt, Mr. George B
# 97                    Greenfield, Mr. William Bertram
# 98               Doling, Mrs. John T (Ada Julia Bone)
#
# [63 rows x 1 columns]

# %%
df[(df["Age"]>15)&(df["Name"].str.startswith("A"))]
# Out:
#     PassengerId  Survived  Pclass  \
# 4             5         0       3
# 13           14         0       3
# 25           26         1       3
# 40           41         0       3
# 49           50         0       3
# 68           69         1       3
# 91           92         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 4                            Allen, Mr. William Henry    male  35.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 68                    Andersson, Miss. Erna Alexandra  female  17.0      4
# 91                         Andreasson, Mr. Paul Edvin    male  20.0      0
#
#     Parch   Ticket     Fare Cabin Embarked
# ...

# %%
df[df["Name"].str.contains("ae|ea")]
# Out:
#     PassengerId  Survived  Pclass  \
# 3             4         1       1
# 33           34         0       2
# 42           43         0       3
# 67           68         0       3
# 80           81         0       3
# 86           87         0       3
# 91           92         0       3
# 93           94         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 33                         Wheadon, Mr. Edward H    male  66.0      0      0
# 42                           Kraeff, Mr. Theodor    male   NaN      0      0
# 67                      Crease, Mr. Ernest James    male  19.0      0      0
# 80                          Waelens, Mr. Achille    male  22.0      0      0
# 86                        Ford, Mr. William Neal    male  16.0      1      3
# 91                    Andreasson, Mr. Paul Edvin    male  20.0      0      0
# ...

# %%
df.query('Age==20 & Sex=="male"')
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 91           92         0       3      Andreasson, Mr. Paul Edvin  male  20.0
#
#     SibSp  Parch     Ticket    Fare Cabin Embarked
# 12      0      0  A/5. 2151  8.0500   NaN        S
# 91      0      0     347466  7.8542   NaN        S

# %%
df['Price']=4.99
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 94           95         0       3
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# #**FILTERING**

# %%
df.loc[df["Age"]>50]
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 6             7         0       1           McCarthy, Mr. Timothy J    male
# 11           12         1       1          Bonnell, Miss. Elizabeth  female
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
# 33           34         0       2             Wheadon, Mr. Edward H    male
# 54           55         0       1    Ostby, Mr. Engelhart Cornelius    male
# 94           95         0       3                 Coxon, Mr. Daniel    male
# 96           97         0       1         Goldschmidt, Mr. George B    male
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Price
# 6   54.0      0      0       17463  51.8625   E46        S   4.99
# 11  58.0      0      0      113783  26.5500  C103        S   4.99
# 15  55.0      0      0      248706  16.0000   NaN        S   4.99
# 33  66.0      0      0  C.A. 24579  10.5000   NaN        S   4.99
# ...

# %%
df.loc[df["Age"]>50,["Name"]]
# Out:
#                                 Name
# 6            McCarthy, Mr. Timothy J
# 11          Bonnell, Miss. Elizabeth
# 15  Hewlett, Mrs. (Mary D Kingcome)
# 33             Wheadon, Mr. Edward H
# 54    Ostby, Mr. Engelhart Cornelius
# 94                 Coxon, Mr. Daniel
# 96         Goldschmidt, Mr. George B

# %% [markdown]
# **Double Condtion**

# %%
df[(df["Age"]>50)&(df["Sex"]=="male")]
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 33           34         0       2           Wheadon, Mr. Edward H  male  66.0
# 54           55         0       1  Ostby, Mr. Engelhart Cornelius  male  65.0
# 94           95         0       3               Coxon, Mr. Daniel  male  59.0
# 96           97         0       1       Goldschmidt, Mr. George B  male  71.0
#
#     SibSp  Parch      Ticket     Fare Cabin Embarked  Price
# 6       0      0       17463  51.8625   E46        S   4.99
# 33      0      0  C.A. 24579  10.5000   NaN        S   4.99
# 54      0      1      113509  61.9792   B30        C   4.99
# 94      0      0      364500   7.2500   NaN        S   4.99
# 96      0      0    PC 17754  34.6542    A5        C   4.99

# %% [markdown]
# **Single or Double Contains & Without case senstive**

# %%
df[df["Name"].str.contains("ae")]
# Out:
#     PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 42           43         0       3   Kraeff, Mr. Theodor  male   NaN      0
# 80           81         0       3  Waelens, Mr. Achille  male  22.0      0
#
#     Parch  Ticket    Fare Cabin Embarked  Price
# 42      0  349253  7.8958   NaN        C   4.99
# 80      0  345767  9.0000   NaN        S   4.99

# %%
df[df["Name"].str.contains("ae",case=False)]
# Out:
#     PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 42           43         0       3   Kraeff, Mr. Theodor  male   NaN      0
# 80           81         0       3  Waelens, Mr. Achille  male  22.0      0
#
#     Parch  Ticket    Fare Cabin Embarked  Price
# 42      0  349253  7.8958   NaN        C   4.99
# 80      0  345767  9.0000   NaN        S   4.99

# %%
df[df["Name"].str.contains("ae|ea",case=False)]
# Out:
#     PassengerId  Survived  Pclass  \
# 3             4         1       1
# 33           34         0       2
# 42           43         0       3
# 67           68         0       3
# 80           81         0       3
# 86           87         0       3
# 91           92         0       3
# 93           94         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 33                         Wheadon, Mr. Edward H    male  66.0      0      0
# 42                           Kraeff, Mr. Theodor    male   NaN      0      0
# 67                      Crease, Mr. Ernest James    male  19.0      0      0
# 80                          Waelens, Mr. Achille    male  22.0      0      0
# 86                        Ford, Mr. William Neal    male  16.0      1      3
# 91                    Andreasson, Mr. Paul Edvin    male  20.0      0      0
# ...

# %% [markdown]
# **ISIN**

# %%
df[df["Embarked"].isin(["C","Q"])]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 5             6         0       3
# 9            10         1       2
# 16           17         0       3
# 19           20         1       3
# 22           23         1       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 39           40         1       3
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 52           53         1       1
# 54           55         0       1
# 57           58         0       3
# 60           61         0       3
# 64           65         0       1
# 65           66         1       3
# ...

# %% [markdown]
# **StartsWith**

# %%
df[df["Name"].str.startswith("Sa")]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 12           13         0       3   Saundercock, Mr. William Henry    male
# 48           49         0       3              Samaan, Mr. Youssef    male
#
#      Age  SibSp  Parch     Ticket     Fare Cabin Embarked  Price
# 10   4.0      1      1    PP 9549  16.7000    G6        S   4.99
# 12  20.0      0      0  A/5. 2151   8.0500   NaN        S   4.99
# 48   NaN      2      0       2662  21.6792   NaN        C   4.99

# %% [markdown]
# **Query**

# %%
df.query('Pclass==1 and Sex=="male"')
# Out:
#     PassengerId  Survived  Pclass                             Name   Sex  \
# 6             7         0       1          McCarthy, Mr. Timothy J  male
# 23           24         1       1     Sloper, Mr. William Thompson  male
# 27           28         0       1   Fortune, Mr. Charles Alexander  male
# 30           31         0       1         Uruchurtu, Don. Manuel E  male
# 34           35         0       1          Meyer, Mr. Edgar Joseph  male
# 35           36         0       1   Holverson, Mr. Alexander Oskar  male
# 54           55         0       1   Ostby, Mr. Engelhart Cornelius  male
# 55           56         1       1                Woolner, Mr. Hugh  male
# 62           63         0       1      Harris, Mr. Henry Birkhardt  male
# 64           65         0       1            Stewart, Mr. Albert A  male
# 83           84         0       1          Carrau, Mr. Francisco M  male
# 92           93         0       1      Chaffee, Mr. Herbert Fuller  male
# ...

# %% [markdown]
# **ADD OR REMOVING COLUMN**

# %%
df["Living_Being_Type"]="Human"

# %%
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 94           95         0       3
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# **ASSIGNING DIFFERNT PRICE BASED ON SOME VALUE**

# %%
import numpy as np
df["new_price"]=np.where(df["Pclass"]==1,100,10)
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 94           95         0       3
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# **To delete Particular Row**

# %%
df.drop(0,inplace=True)

# %% [markdown]
# **To Delete Particular Column**

# %%
df.drop(columns=["Price"],inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked Living_Being_Type  \
# 1      0          PC 17599  71.2833   C85        C             Human
# 2      0  STON/O2. 3101282   7.9250   NaN        S             Human
# 3      0            113803  53.1000  C123        S             Human
# ...

# %% [markdown]
# **To Get Extra Column Renvenue**

# %%
df["Revenue"]=df["Pclass"]*df["new_price"]
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked Living_Being_Type  \
# 1      0          PC 17599  71.2833   C85        C             Human
# 2      0  STON/O2. 3101282   7.9250   NaN        S             Human
# 3      0            113803  53.1000  C123        S             Human
# ...

# %% [markdown]
# **To Rename**

# %%
df = df.rename(columns={"new_price": "Price"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked Living_Being_Type  Price  \
# 1      0          PC 17599  71.2833   C85        C             Human    100
# 2      0  STON/O2. 3101282   7.9250   NaN        S             Human     10
# 3      0            113803  53.1000  C123        S             Human    100
# ...

# %% [markdown]
# df=df.rename(columns={})

# %% [markdown]
# **To copy one data into another**

# %%
df_copy=df.copy()
df_copy.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  20.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Living_Being_Type  Price  \
# 1      0          PC 17599  71.2833   C85        C             Human    100
# 2      0  STON/O2. 3101282   7.9250   NaN        S             Human     10
#
#    Revenue
# 1      100
# 2       30

# %% [markdown]
# **COMMON NAME**

# %%
df["Common Name"]=df["Name"].str.split(",").str[0]
df.tail(2)
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 97           98         1       1       Greenfield, Mr. William Bertram
# 98           99         1       2  Doling, Mrs. John T (Ada Julia Bone)
#
#        Sex   Age  SibSp  Parch    Ticket     Fare    Cabin Embarked  \
# 97    male  23.0      0      1  PC 17759  63.3583  D10 D12        C
# 98  female  34.0      0      1    231919  23.0000      NaN        S
#
#    Living_Being_Type  Price  Revenue Common Name
# 97             Human    100      100  Greenfield
# 98             Human     10       20      Doling
