# %%
import pandas as pd

# %%
df=pd.read_csv("pandas_practice.csv")

# %%
df

# %%
most_common = df['Cabin'].mode()[0]
df['Cabin'] = df['Cabin'].fillna(most_common)

# %%
df

# %%
df.fillna(0,inplace=True)

# %%
df
